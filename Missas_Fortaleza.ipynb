# %% [markdown]
# <a href="https://colab.research.google.com/github/viniciusgomesbatista/ocr/blob/main/Missas_Fortaleza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
pip install tika
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32625 sha256=ad7d6a03af2fbe3846a9017f7004ec54ab0110401e574dde9667e219c01ea7be
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
# Successfully built tika
# ...

# %%
from tika import parser

# %%
import pandas as pd

# %%
raw = parser.from_file('/content/drive/MyDrive/Lumen/Missas Fortaleza/Missas.pdf')
# Out:
# 2023-06-08 18:56:23,872 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar to /tmp/tika-server.jar.
# 2023-06-08 18:56:24,356 [MainThread  ] [INFO ]  Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# INFO:tika.tika:Retrieving http://search.maven.org/remotecontent?filepath=org/apache/tika/tika-server-standard/2.6.0/tika-server-standard-2.6.0.jar.md5 to /tmp/tika-server.jar.md5.
# 2023-06-08 18:56:24,669 [MainThread  ] [WARNI]  Failed to see startup log message; retrying...
# WARNING:tika.tika:Failed to see startup log message; retrying...

# %%
content = raw['content']

# %%
editado = content.split('\n')

# %%
dados = [x.split(", '',") for x in editado]

# %%
df = pd.DataFrame(dados)

# %%
df = df[~df[0].str.contains('Áreas Pastorais e Santuários')]

# %%
df.to_csv(r'/content/drive/MyDrive/Lumen/Missas Fortaleza/Missas.csv')

# %% [markdown]
# Limpeza parte 2

# %%
df = pd.read_csv(r'/content/drive/MyDrive/Lumen/Missas Fortaleza/Missas - Página1.csv')

# %%
df.columns
# Out:
# Index(['Info', 'Detalhe', 'Tipo'], dtype='object')

# %%
df.loc[(df['Tipo'] =="Paróquia") | (df['Tipo'] =="-")]
df = df[['Info','Detalhe']]

# %%
df['Detalhe'].fillna(df['Info'], inplace=True)

# %%
df.head(33)
# Out:
#                                      Info  \
# 0                                 domingo
# 1                                 segunda
# 2                                   terça
# 3                                  quarta
# 4                                  quinta
# 5                                   sexta
# 6    Horário de Atendimento da Secretaria
# 7                                  sabado
# 8                                 domingo
# 9                                 segunda
# 10                                  terça
# 11                                 quarta
# 12                                 quinta
# 13                                  sexta
# 14                                 sabado
# 15                      Horário de Missas
# 16                          CEP da Matriz
# 17                                    Pe.
# 18                         Casa_Paroquial
# 19                                Celular
# 20                                   Site
# ...

# %%
array = np.array(df['Detalhe'])

# %%
new_shape = (151, 33)
reshaped_array = np.reshape(array, new_shape)

# %%
df_1 = pd.DataFrame(reshaped_array)

# %%
df_1.head()
# Out:
#           0        1      2       3       4      5   \
# 0   7h | 19h  segunda  terça  quarta  quinta  sexta
# 1    domingo  segunda  terça  quarta  quinta  sexta
# 2    domingo  segunda  terça  quarta  quinta  sexta
# 3  8h  | 19h  segunda  terça  quarta     19h  sexta
# 4    9h |19h  segunda  terça  quarta  quinta  sexta
#
#                                      6       7                       8   \
# 0  Horário de Atendimento da Secretaria  sabado  6h às 7h | 18h às 19h
# 1  Horário de Atendimento da Secretaria  sabado                 domingo
# 2  Horário de Atendimento da Secretaria  sabado                 domingo
# 3  Horário de Atendimento da Secretaria  sabado                 domingo
# 4  Horário de Atendimento da Secretaria  sabado                 domingo
#
#                         9   ...                                         23  \
# 0   7h às 12h | 14h às 17h  ...       paroquiajoaobatistaacarape@gmail.com
# ...

# %%
lista = df['Info'].head(33).tolist()

# %%
lista
# Out:
# ['domingo',
#  'segunda',
#  'terça',
#  'quarta',
#  'quinta',
#  'sexta',
#  'Horário de Atendimento da Secretaria',
#  'sabado',
#  'domingo',
#  'segunda',
#  'terça',
#  'quarta',
#  'quinta',
#  'sexta',
#  'sabado',
#  'Horário de Missas',
#  'CEP da Matriz',
#  'Pe.',
#  'Casa_Paroquial',
#  'Celular',
#  'Site',
#  'Acarape',
#  'Pároco José Almir Martins Jucá Júnior',
#  'E-mail',
#  'Fone',
#  'Acarape-CE',
#  '419',
#  'Cidade',
#  'Bairro',
#  'Endereço',
#  'São João BatistaParóquia',
#  'Região',
#  'Secretário(a)']

# %%
df_1.columns = lista

# %%
df_1.head()
# Out:
#      domingo  segunda  terça  quarta  quinta  sexta  \
# 0   7h | 19h  segunda  terça  quarta  quinta  sexta
# 1    domingo  segunda  terça  quarta  quinta  sexta
# 2    domingo  segunda  terça  quarta  quinta  sexta
# 3  8h  | 19h  segunda  terça  quarta     19h  sexta
# 4    9h |19h  segunda  terça  quarta  quinta  sexta
#
#    Horário de Atendimento da Secretaria  sabado                 domingo  \
# 0  Horário de Atendimento da Secretaria  sabado  6h às 7h | 18h às 19h
# 1  Horário de Atendimento da Secretaria  sabado                 domingo
# 2  Horário de Atendimento da Secretaria  sabado                 domingo
# 3  Horário de Atendimento da Secretaria  sabado                 domingo
# 4  Horário de Atendimento da Secretaria  sabado                 domingo
#
#                    segunda  ...                                     E-mail  \
# 0   7h às 12h | 14h às 17h  ...       paroquiajoaobatistaacarape@gmail.com
# ...

# %%
df_1.to_csv(r'/content/drive/MyDrive/Lumen/Missas Fortaleza/Final.csv', index=False)
